# %%
print("hello")
# Out:
# hello

# %%
pip install transformers
# Out:
# ...
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached huggingface_hub-0.26.3-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached tokenizers-0.20.3-cp311-none-win_amd64.whl.metadata (6.9 kB)
# ...
#   Using cached safetensors-0.4.5-cp311-none-win_amd64.whl.metadata (3.9 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached transformers-4.46.3-py3-none-any.whl (10.0 MB)
# Using cached huggingface_hub-0.26.3-py3-none-any.whl (447 kB)
# Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Using cached safetensors-0.4.5-cp311-none-win_amd64.whl (285 kB)
# Using cached tokenizers-0.20.3-cp311-none-win_amd64.whl (2.4 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...

# %%
pip install transformers datasets torchaudio
# Out:
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pip\_internal\cli\req_command.py", line 245, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
# ...

# %%
pip install transformers torch soundfile torchaudio
# Out:
# ...
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached torch-2.5.1-cp311-cp311-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached torchaudio-2.5.1-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ...
# Using cached transformers-4.46.3-py3-none-any.whl (10.0 MB)
# ...
#    ---------------------------------------- 0.0/203.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/203.1 MB 1.4 MB/s eta 0:02:29
#    ---------------------------------------- 0.1/203.1 MB 1.3 MB/s eta 0:02:35
#    ---------------------------------------- 0.3/203.1 MB 2.5 MB/s eta 0:01:20
#    ---------------------------------------- 0.6/203.1 MB 3.3 MB/s eta 0:01:01
#    ---------------------------------------- 0.7/203.1 MB 3.6 MB/s eta 0:00:56
#    ---------------------------------------- 1.0/203.1 MB 3.7 MB/s eta 0:00:56
#    ---------------------------------------- 1.1/203.1 MB 3.7 MB/s eta 0:00:56
# ...

# %%
pip install transformers datasets huggingface_hub
# Out:
# ...
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached pyarrow-18.1.0-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached aiohttp-3.11.8-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# ...
#   Using cached aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached frozenlist-1.5.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached multidict-6.1.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached propcache-0.2.0-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# ...
#   Using cached yarl-1.18.0-cp311-cp311-win_amd64.whl.metadata (69 kB)
# ...

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer
import torch
import soundfile as sf
from torchaudio.transforms import Resample
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer
#       2 import torch
#       3 import soundfile as sf
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# ...

# %%
model_path = r"C:\Users\Acer\Downloads\model.safetensors"  # Replace with your model directory "C:\Users\Acer\Downloads\model.safetensors"
tokenizer_path = r"C:\Users\Acer\Downloads\vocab"  # Replace with your tokenizer directory

# %%
tokenizer=AutoTokenizer.from_pretrained(tokenizer_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tokenizer=AutoTokenizer.from_pretrained(tokenizer_path)
#
# NameError: name 'AutoTokenizer' is not defined
